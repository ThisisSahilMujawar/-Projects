# %% [markdown]
# <h2>Importing important libraries </h2>

# %%
import pandas as pd
import os

# %% [markdown]
# <h3>Specical step i took to remove the column which had NAN value</h3>

# %%
# df = pd.read_csv('./Sales_Data/Sales_April_2019.csv')
# df.drop([1], axis=0, inplace=True)

# df.reset_index()
# df.to_csv('./Sales_Data/Sales_April_2019.csv')

# %% [markdown]
# <h2>Merging All Sales of different months into a single Dataframe</h2>

# %%
files = [file for file in os.listdir('./Sales_Data')]
print(files)
# Out:
# ['Sales_April_2019.csv', 'Sales_August_2019.csv', 'Sales_December_2019.csv', 'Sales_February_2019.csv', 'Sales_January_2019.csv', 'Sales_July_2019.csv', 'Sales_June_2019.csv', 'Sales_March_2019.csv', 'Sales_May_2019.csv', 'Sales_November_2019.csv', 'Sales_October_2019.csv', 'Sales_September_2019.csv']

# %%
all_df = pd.DataFrame()
print(all_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for file in files:
    df = pd.read_csv('./Sales_Data./'+file)      
    all_df = pd.concat([all_df, df])
all_df
# Out:
#        Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0             0.0   176558        USB-C Charging Cable                2
# 1             2.0   176559  Bose SoundSport Headphones                1
# 2             3.0   176560                Google Phone                1
# 3             4.0   176560            Wired Headphones                1
# 4             5.0   176561            Wired Headphones                1
# ...           ...      ...                         ...              ...
# 11681         NaN   259353      AAA Batteries (4-pack)                3
# 11682         NaN   259354                      iPhone                1
# 11683         NaN   259355                      iPhone                1
# 11684         NaN   259356      34in Ultrawide Monitor                1
# 11685         NaN   259357        USB-C Charging Cable                1
#
#       Price Each      Order Date                         Purchase Address
# ...

# %%
all_df.to_csv('all_data.csv', index = False)

# %% [markdown]
# <h3> Read in Updated DataFrame</h3>

# %%
all_df = pd.read_csv('all_data.csv')
all_df
# Out:
#         Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0              0.0   176558        USB-C Charging Cable                2
# 1              2.0   176559  Bose SoundSport Headphones                1
# 2              3.0   176560                Google Phone                1
# 3              4.0   176560            Wired Headphones                1
# 4              5.0   176561            Wired Headphones                1
# ...            ...      ...                         ...              ...
# 186844         NaN   259353      AAA Batteries (4-pack)                3
# 186845         NaN   259354                      iPhone                1
# 186846         NaN   259355                      iPhone                1
# 186847         NaN   259356      34in Ultrawide Monitor                1
# 186848         NaN   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address
# ...

# %%
all_df.drop(columns = all_df.columns.values[0],inplace = True)

# %%
all_df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186844   259353      AAA Batteries (4-pack)                3       2.99
# 186845   259354                      iPhone                1        700
# 186846   259355                      iPhone                1        700
# 186847   259356      34in Ultrawide Monitor                1     379.99
# 186848   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_df.columns
# Out:
# Index(['Unnamed: 0', 'Order ID', 'Product', 'Quantity Ordered', 'Price Each',
#        'Order Date', 'Purchase Address'],
#       dtype='object')

# %%
all_df.drop(columns = all_df.columns.values[0],inplace = True)

# %%
all_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# <h4>Q.1 What was the best month for sales? How much was earned that month? </h4>

# %% [markdown]
# <h4> Task 1 : Adding a month column </h4>

# %%
all_df['Month'] = all_df['Order Date'].str[0:2]

# %%
all_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1       176559  Bose SoundSport Headphones                1      99.99
# 2       176560                Google Phone                1        600
# 3       176560            Wired Headphones                1      11.99
# 4       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# ...

# %% [markdown]
# <h3>Cleaning Up the Data</h3>

# %% [markdown]
# <h4>Identifying NAN values</h4>

# %%
# type(all_df.isna().any(axis=1))
(all_df.isna().any(axis =1))         #gives series of boolean values which have atleast one null and axis =1 means this applying function along the row
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11681    False
# 11682    False
# 11683    False
# 11684    False
# 11685    False
# Length: 186849, dtype: bool

# %%
null_df = all_df[all_df.isna().any(axis =1)]

# %%
null_df.index
# Out:
# Index([   355,    734,   1432,   1552,   1570,   1991,   2264,   2797,   3023,
#          3097,
#        ...
#        184407, 184545, 184835, 185016, 185099, 185175, 185437, 186041, 186547,
#        186825],
#       dtype='int64', length=544)

# %%
all_df.drop(null_df.index, inplace = True)
all_df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186844   259353      AAA Batteries (4-pack)                3       2.99
# 186845   259354                      iPhone                1        700
# 186846   259355                      iPhone                1        700
# 186847   259356      34in Ultrawide Monitor                1     379.99
# 186848   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_df.isna().any(axis =0)
# Out:
# Order ID            False
# Product             False
# Quantity Ordered    False
# Price Each          False
# Order Date          False
# Purchase Address    False
# dtype: bool

# %%
# Another way to drop NAN values
# all_df = all_df.dropna(how = 'all')
# all_df
all_df['Month'].str[0:2] == 'Or'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11681    False
# 11682    False
# 11683    False
# 11684    False
# 11685    False
# Name: Month, Length: 181300, dtype: bool

# %%
temp_df = all_df[all_df['Month'].str[0:2] == 'Or']
temp_df
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 518     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1148    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1154    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2877    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2892    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 185163  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185550  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186562  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186631  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186737  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month
# 518     Purchase Address    Or
# 1148    Purchase Address    Or
# 1154    Purchase Address    Or
# ...

# %%
# Droping the column which have str 'Or' in month or Order Date column 
# all_df = all_df[(all_df['Month'].str[0:2] != 'Or')]
# all_df

# %%
# temp_df = all_df[all_df['Month'].str[0:2] == 'Or']
# temp_df

# %%
all_df.drop(temp_df.index, inplace = True)

# %%
all_df['Month'] = all_df['Month'].astype('int32')

# %% [markdown]
# <h3>Solution of the Question </h3>

# %%
all_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1       176559  Bose SoundSport Headphones                1      99.99
# 2       176560                Google Phone                1        600
# 3       176560            Wired Headphones                1      11.99
# 4       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address  Month
# ...

# %% [markdown]
# <h3>Converting each column dtype to Suitable Data Type</h3>

# %%
all_df['Quantity Ordered'] = pd.to_numeric(all_df['Quantity Ordered'])

# %%
all_df['Price Each'] =pd.to_numeric(all_df['Price Each'])

# %%
all_df['Sales'] = all_df['Quantity Ordered'] * all_df['Price Each']
all_df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 1       176559  Bose SoundSport Headphones                 1       99.99
# 2       176560                Google Phone                 1      600.00
# 3       176560            Wired Headphones                 1       11.99
# 4       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 11681   259353      AAA Batteries (4-pack)                 3        2.99
# 11682   259354                      iPhone                 1      700.00
# 11683   259355                      iPhone                 1      700.00
# 11684   259356      34in Ultrawide Monitor                 1      379.99
# 11685   259357        USB-C Charging Cable                 1       11.95
#
#            Order Date                         Purchase Address  Month   Sales
# ...

# %%
results = all_df.groupby(['Month']).()['Sales']
results
# Out:
# Month
# 1     1720136.99
# 2     2093015.10
# 3     2672156.88
# 4     3250102.88
# 5     3012793.98
# 6     2442292.03
# 7     2510268.52
# 8     2118753.88
# 9     1990379.12
# 10    3594342.74
# 11    3068777.63
# 12    4480850.36
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
months = range(1,13)
    
plt.bar(months, results )
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month Number')
plt.show()

# %% [markdown]
#  <h2>What City had the highest number of Sales?</h2>

# %%
all_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
all_df.tail()
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 186844   259353  AAA Batteries (4-pack)                 3        2.99
# 186845   259354                  iPhone                 1      700.00
# 186846   259355                  iPhone                 1      700.00
# 186847   259356  34in Ultrawide Monitor                 1      379.99
# 186848   259357    USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# 186844  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001      9    8.97
# 186845  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016      9  700.00
# 186846  09/23/19 07:39     220 12th St, San Francisco, CA 94016      9  700.00
# 186847  09/19/19 17:30   511 Forest St, San Francisco, CA 94016      9  379.99
# 186848  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016      9   11.95

# %%
import re

# %% [markdown]
# <h3>Task 1 : Add a city Column</h3>

# %%
all_df['City'] = all_df['Purchase Address'].str.extract(', (.*?),')
all_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186844   259353      AAA Batteries (4-pack)                 3        2.99
# 186845   259354                      iPhone                 1      700.00
# 186846   259355                      iPhone                 1      700.00
# 186847   259356      34in Ultrawide Monitor                 1      379.99
# 186848   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# <h3>Task 2: Created a function which can extract city name along with the country state</h3>

# %%
def City_US(address):
    return address.split(',')[1].split(' ',maxsplit = 1)[1]
def State_US(address):
    return address.split(',')[2].split(' ')[1]

all_df['City'] = all_df['Purchase Address'].apply(lambda x: f"{City_US(x)} ({State_US(x)})")

# %%
all_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City
# 0       Dallas (TX)
# 1       Boston (MA)
# 2  Los Angeles (CA)
# 3  Los Angeles (CA)
# ...

# %% [markdown]
# <h3>Task 3: Writing a solution and Plotting it on a bar chart</h3>

# %%
results2 = all_df.groupby('City').sum()['Sales']

# %%
results2.index
# Out:
# Index(['Atlanta (GA)', 'Austin (TX)', 'Boston (MA)', 'Dallas (TX)',
#        'Los Angeles (CA)', 'New York City (NY)', 'Portland (ME)',
#        'Portland (OR)', 'San Francisco (CA)', 'Seattle (WA)'],
#       dtype='object', name='City')

# %%
Cities = list(results2.index)
Cities
# Out:
# ['Atlanta (GA)',
#  'Austin (TX)',
#  'Boston (MA)',
#  'Dallas (TX)',
#  'Los Angeles (CA)',
#  'New York City (NY)',
#  'Portland (ME)',
#  'Portland (OR)',
#  'San Francisco (CA)',
#  'Seattle (WA)']

# %%
plt.bar(Cities, results2 )
plt.xticks(Cities, rotation = 'vertical', size = 8)
plt.ylabel('Sales in USD ($)')
plt.xlabel('City')
plt.show()

# %% [markdown]
# <h3>Question 3: What time should we display advertisements to maximize likelihood of customer's buying products</h3>

# %%
all_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City
# 0       Dallas (TX)
# 1       Boston (MA)
# 2  Los Angeles (CA)
# 3  Los Angeles (CA)
# ...

# %% [markdown]
# <h3>Task 1: Change dtype of 'Order Type' column to datetime format </h3>

# %%
all_df['Order Date'] = pd.to_datetime(all_df['Order Date'],format='%m/%d/%y %H:%M') 
# all_df['Order Date'] = all_df['Order Date'].astype(str)

# %%
all_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City Time
# 0       Dallas (TX)   08
# 1       Boston (MA)   22
# ...

# %%
all_df['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
all_df['Time'] = all_df['Order Date'].dt.strftime('%H:%M')

# %%
# all_df['Time'] = pd.to_datetime(all_df['Time'],format='%H:%M')

# %%
# all_df.head()

# %%
# all_df['Time'].dtype

# %%
all_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City   Time
# 0       Dallas (TX)  08:46
# 1       Boston (MA)  22:30
# ...

# %%
# all_df.drop(columns = ['Time'])
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186844   259353      AAA Batteries (4-pack)                 3        2.99
# 186845   259354                      iPhone                 1      700.00
# 186846   259355                      iPhone                 1      700.00
# 186847   259356      34in Ultrawide Monitor                 1      379.99
# 186848   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
all_df['Time'] = all_df['Time'].astype(str)
all_df['Order Date'] = all_df['Order Date'].astype(str)
def get_time(date):
    return date.split(' ',maxsplit = 1)[1].rsplit(':',maxsplit = 1)[0]
all_df['Time'] = all_df['Order Date'].apply(lambda x: get_time(x))
all_df['Time']
# Out:
# 0         08:46
# 1         22:30
# 2         14:38
# 3         14:38
# 4         09:27
#           ...
# 186844    20:56
# 186845    16:00
# 186846    07:39
# 186847    17:30
# 186848    00:18
# Name: Time, Length: 185950, dtype: object

# %%
all_df['Time'][0]
# Out:
# '08:46'

# %%
# all_df.drop(columns = ['Exact Time'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 all_df.drop(columns = ['Exact Time'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
# ...

# %%
def get_min(time):
    s = int(time.split(':')[0])
    r = int(time.split(':')[1])
    if r> 30:
        return s+1
    else:
        return s

all_df['Exact Time'] = all_df['Time'].apply(lambda x: get_min(x))

# %%
all_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#             Order Date                      Purchase Address  Month   Sales  \
# 0  2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1  2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City   Time  Exact Time
# 0       Dallas (TX)  08:46           9
# ...

# %%
all_df['Exact Time'].dtype
# Out:
# dtype('int64')

# %%
all_df.loc[all_df['Exact Time'] == 24,'Exact Time'] = 0
all_df.head()
all_df['Count'] = 1
all_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#             Order Date                      Purchase Address  Month   Sales  \
# 0  2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1  2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City   Time  Exact Time  Count
# 0       Dallas (TX)  08:46           9      1
# ...

# %%
all_df.groupby('Exact Time').sum()['Count']
# Out:
# Exact Time
# 0      5037
# 1      2972
# 2      1707
# 3       950
# 4       775
# 5      1025
# 6      1860
# 7      3216
# 8      5071
# 9      7607
# 10     9926
# 11    11890
# 12    12533
# 13    12566
# 14    11354
# 15    10613
# 16    10150
# 17    10615
# 18    11485
# 19    12813
# 20    12728
# 21    11667
# 22     9872
# 23     7518
# Name: Count, dtype: int64

# %%
results3 = all_df.groupby('Exact Time').sum()['Count']
Hour = list(results3.index)
plt.bar(Hour, results3 )
plt.xticks(Hour, rotation = 'vertical', size = 8)
plt.ylabel('Best Time')
plt.xlabel('Hour')
plt.show()

# %% [markdown]
# <h3>Question 4 What products are most often sold together ?</h3>

# %%
all_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
all_df['Order ID'].duplicated(keep = False)
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 186844    False
# 186845    False
# 186846    False
# 186847    False
# 186848    False
# Name: Order ID, Length: 185950, dtype: bool

# %%
df = all_df[all_df['Order ID'].duplicated(keep = False)]
# df = df.drop(columns = df.columns.values[9:])

# %%
df.head(10)
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 2     176560                Google Phone                1        600
# 3     176560            Wired Headphones                1      11.99
# 17    176574                Google Phone                1        600
# 18    176574        USB-C Charging Cable                1      11.95
# 29    176585  Bose SoundSport Headphones                1      99.99
# 30    176585  Bose SoundSport Headphones                1      99.99
# 31    176586      AAA Batteries (4-pack)                2       2.99
# 32    176586                Google Phone                1        600
# 118   176672    Lightning Charging Cable                1      14.95
# 119   176672        USB-C Charging Cable                1      11.95
#
#          Order Date                        Purchase Address Month
# 2    04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001    04
# 3    04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001    04
# ...

# %%
# df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))    same step as below
# avoided warning signs using .loc:
df.loc[:, 'Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df
# Out:
# C:\Users\Sahil\AppData\Local\Temp\ipykernel_10288\1384824480.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#        Order ID                     Product Quantity Ordered Price Each  \
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 17       176574                Google Phone                1        600
# 18       176574        USB-C Charging Cable                1      11.95
# 29       176585  Bose SoundSport Headphones                1      99.99
# ...         ...                         ...              ...        ...
# ...

# %%
df = df[['Order ID','Grouped']].drop_duplicates()

# %%
df.head()
# Out:
#     Order ID                                            Grouped
# 2     176560                      Google Phone,Wired Headphones
# 17    176574                  Google Phone,USB-C Charging Cable
# 29    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 31    176586                AAA Batteries (4-pack),Google Phone
# 118   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter

# %%
count = Counter()
for row in df['Grouped']:    
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# <h3>Q.5 What product sold the most? Why do you think it sold the most?</h3>

# %%
all_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
all_df.drop(columns = ['Month'],inplace = True)

# %%
all_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_df.groupby('Product').sum()['Quantity Ordered']
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
results4 = all_df.groupby('Product').sum()['Quantity Ordered']
results4.index
Products = list(results4.index)
Products
plt.bar(Products, results4 )
plt.xticks(Products, rotation = 'vertical', size = 8)
plt.ylabel('Quantity Ordered')
plt.xlabel('Product')
plt.show()

# %%
all_df['Price Each'].dtype
# Out:
# dtype('float64')

# %%
all_df['Price Each'] = all_df['Price Each'].astype('float64')

prices = all_df.groupby('Product')['Price Each'].mean()
prices
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
prices = all_df.groupby('Product')['Price Each'].mean()

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(Products, results4, color='g')
ax2.plot(Products, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(Products, rotation='vertical', size=8)

fig.show()
plt.show()
# Out:
# C:\Users\Sahil\AppData\Local\Temp\ipykernel_10288\982151262.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(Products, rotation='vertical', size=8)
# C:\Users\Sahil\AppData\Local\Temp\ipykernel_10288\982151262.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
